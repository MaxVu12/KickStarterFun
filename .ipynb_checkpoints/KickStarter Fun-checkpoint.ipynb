# %%
import numpy as np 
import pandas as pd 
#pd.set_option('float_format', '{:f}'.format)
pd.options.display.float_format = '{:,.2f}'.format
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filename = "kickstarter-projects/ks-projects-201801.csv"
ks_df = pd.read_csv(filename)
ks_df.shape
# Out:
# (378661, 15)

# %%
ks_df = ks_df.dropna()
ks_df.shape
# Out:
# (374860, 15)

# %%
ks_df.describe()
# Out:
#                     ID           goal       pledged    backers   usd pledged  \
# count       374,860.00     374,860.00    374,860.00 374,860.00    374,860.00
# mean  1,074,652,355.55      49,522.99      9,750.54     106.69      7,036.80
# std     619,136,772.59   1,189,361.60     96,010.94     911.71     78,640.16
# min           5,971.00           0.01          0.00       0.00          0.00
# 25%     538,063,323.00       2,000.00         31.00       2.00         16.98
# 50%   1,075,289,160.00       5,500.00        620.00      12.00        394.76
# 75%   1,610,137,350.75      16,500.00      4,080.00      57.00      3,034.43
# max   2,147,476,221.00 100,000,000.00 20,338,986.27 219,382.00 20,338,986.27
#
#        usd_pledged_real  usd_goal_real
# count        374,860.00     374,860.00
# mean           9,120.90      45,863.03
# std           91,319.69   1,158,767.37
# min                0.00           0.01
# 25%               31.00       2,000.00
# 50%              624.50       5,500.00
# 75%            4,050.89      16,000.00
# max       20,338,986.27 166,361,390.71

# %%
avg_goal_per_project = ks_df.groupby("ID").sum()['usd_goal_real'].mean()
avg_goal_per_project
# Out:
# 45863.02597164258

# %%
avg_pledged_per_project = ks_df.groupby("ID").sum()['usd_pledged_real'].mean()
avg_pledged_per_project
# Out:
# 9120.898548951944

# %%
avg_pledged_per_project / avg_goal_per_project * 100
# Out:
# 19.88725853935468

# %% [markdown]
# # Spare code used in early data exploration

# %%
ks_df.country.unique()
# Out:
# array(['GB', 'US', 'CA', 'AU', 'NO', 'IT', 'DE', 'IE', 'MX', 'ES', 'N,0"',
#        'SE', 'FR', 'NL', 'NZ', 'CH', 'AT', 'DK', 'BE', 'HK', 'LU', 'SG',
#        'JP'], dtype=object)

# %%
 np.where(pd.isnull(ks_df))
# Out:
# (array([   169,    328,    632, ..., 378434, 378585, 378588]),
#  array([12, 12, 12, ..., 12, 12, 12]))

# %%
ks_df.iloc[[378588]]
# Out:
#                ID                            name    category main_category  \
# 378588  999621278  Jeune auteur a besoin de vous!  Publishing    Publishing
#
#        currency    deadline     goal             launched  pledged      state  \
# 378588      EUR  2015-11-20 1,600.00  2015-10-21 21:28:13     0.00  undefined
#
#         backers country  usd pledged  usd_pledged_real  usd_goal_real
# 378588        0    N,0"          nan              0.00       1,710.08

# %%
ks_df.loc[ks_df['state'] == 'undefined'].shape
# Out:
# (3562, 15)

# %%
temp = ks_df[ks_df['usd pledged'].isnull()]

# %%
temp.state.unique()
# Out:
# array(['undefined', 'successful', 'canceled', 'failed', 'suspended',
#        'live'], dtype=object)

# %%
temp.loc[temp['state'] != 'undefined']
# Out:
#                 ID                                               name  \
# 2457    1012744036          An Oratorio for our Time - Last Stop Cafe
# 4338    1022254171         Help OrphanSporks Record Our Fourth Album!
# 4892    1024989802                   Jackson Ruby: The Cassette Album
# 5353    1027275369        Help Parker Brown make his first solo album
# 5597    1028691308          Help BETHANY record a NEW single in Nash!
# 8260    1041708793       Serena Gabriel's first CD!!!!!!: Diving Deep
# 10086   1050790557  Leicester's Days of Glory, a 360º Virtual Real...
# 10527   1052925597   Debut Folk / Rock Album by The Blacklist Social!
# 11191   1056135281                            Begin My Journey in Art
# 13001   1065249597  SCiO: Your Sixth Sense. A Pocket Molecular Sen...
# 13048   1065509232                                 LUME Festival 2016
# 14385   1072430236                The Box -- A Story of Love and Loss
# 14527   1073104639                              SUNN - EP - Pre-vente
# 16769   1084993156  Willy Tea, Chris Doud and Chums: The Children'...
# 17525   1088937473                             Save Us From Ourselves
# 17563    108917939                                  Contrast Magazine
# 18716    109485541                                 The Gifted Journey
# 21385    110837091                                      Nathan Menard
# 23172   1117631926        Jesse Henry's Desert Songwriting Sabbatical
# 23936   1121497013                     109: A Midwest Media Franchise
# 24079   1122231399                          Fill Your Empty Practice!
# 25975   1131956331      Porter Band "Make Jesus Famous" Album Support
# 32215   1163771028         Prince Rogers Nelson Memorial Music School
# 32500   1165084901           School for Classics Songwriting Workshop
# 38162   1193593924                  UNDERSTANDING PLYOMETRIC TRAINING
# 42065    121413755                              have you seen jordan?
# 44594   1226622252                  Documentary: A Child Of Their Own
# 44765   1227315610                                        SourKoolaid
# 44910   1228019792                                 Rock the Farmagain
# 46952   1238892978  kopascetic - Ryan David Orr's 6th full-length ...
# ...            ...                                                ...
# 323142   715827259  Jes Spires Music Recording Project and Album R...
# 324209   721338336        Applegate Trails Association Thru-Hike Film
# 324244   721515702  Haze Gray Decks: Cards Against Humanity joins ...
# 324571   723130569  The Dream Room Project : A Solar Mobile Record...
# 325711   728946373   Equipment funding for innovative sound-architect
# 326852    73476382              Cabin Tapes Web Series: Vinyl Edition
# 332040   761593352  Help Fund an Aspiring young Entrepreneur: #11 ...
# 338430   793819587  Crystal Bowls, Mantra, and Meditation- Soulful...
# 338481   794097378    The Order of the Four Circles: The Order Reborn
# 338549   794535445                                               NLRU
# 340562   804655618                                             REAVES
# 341257   808183588                Before the Bright Lights, Take Two!
# 344315   823779197                   Ever Heard the Contrabass Flute?
# 344755   826085967                                    We Are Mermaids
# 345389   829428239                              Red Alert Productions
# 348821    84711701                       Newburgh: Beauty and Tragedy
# 350302   854648390  Crystal Radio, Vinyl, Wooden Record, Playing C...
# 356090   883814674                                   North Kent Radio
# 360017   904098650  The Original Human Diet Study by Dr. Mondovecchio
# 360465   906504187           The Springtails are making a new record!
# 363806   923603114  The Bench- A Mental Health and Suicide Prevent...
# 367884   944349765  WSU Chorale's 2013 Italy Concert Tour: An A Ca...
# 368641   948175095      Typewriter John and the Blue Strings Debut EP
# 368860   949209229  Be A Catalyst!!!! Help Casey Clark make a name...
# 368889   949401487          A Taste of San Diego's Singer Songwriters
# 371277   961951460  Jahque Inc. is merging with Reesi's Cakes 'N T...
# 371387   962477474                              Spoken Fruit Magazine
# 372375   967557880             Help Danelle Finish Her First EP Album
# 375359   982919439                                              Faith
# 378188   997793413         Whisper Violet - Honors Senior Thesis Film
#
#              category main_category currency    deadline       goal  \
# 2457            Music         Music      USD  2016-05-26   5,000.00
# 4338            Music         Music      USD  2016-05-14   2,500.00
# 4892            Music         Music      USD  2016-05-11   5,000.00
# 5353            Music         Music      USD  2016-05-21   3,800.00
# 5597            Music         Music      USD  2016-05-08   3,500.00
# 8260            Music         Music      USD  2016-05-01   3,500.00
# 10086    Film & Video  Film & Video      GBP  2016-05-29   6,000.00
# 10527           Music         Music      CAD  2016-05-20   6,000.00
# 11191           Music         Music      USD  2016-04-24   1,500.00
# 13001        Hardware    Technology      USD  2014-06-15 200,000.00
# 13048           Music         Music      GBP  2016-05-12   3,500.00
# 14385      Publishing    Publishing      USD  2016-05-30   4,500.00
# 14527           Music         Music      CAD  2016-05-04   4,000.00
# 16769           Music         Music      USD  2013-04-09   3,750.00
# 17525           Music         Music      USD  2016-05-03   5,000.00
# 17563      Publishing    Publishing      USD  2016-05-02   7,500.00
# 18716      Publishing    Publishing      USD  2016-05-11   1,200.00
# 21385           Music         Music      USD  2016-05-07   8,000.00
# 23172           Music         Music      USD  2016-04-25   1,800.00
# 23936           Music         Music      USD  2016-05-08   3,500.00
# 24079      Publishing    Publishing      GBP  2016-05-17   2,000.00
# 25975           Music         Music      USD  2016-05-28   6,000.00
# 32215           Music         Music      USD  2016-05-22   5,000.00
# 32500           Music         Music      USD  2016-05-22   4,000.00
# 38162      Publishing    Publishing      GBP  2016-04-29   5,000.00
# 42065           Music         Music      USD  2016-06-22   3,200.00
# 44594    Film & Video  Film & Video      USD  2016-05-13  15,000.00
# 44765           Music         Music      USD  2016-05-19   5,000.00
# 44910           Music         Music      USD  2016-06-01   1,200.00
# 46952           Music         Music      USD  2016-05-17   3,500.00
# ...               ...           ...      ...         ...        ...
# 323142          Music         Music      USD  2016-05-30   2,000.00
# 324209   Film & Video  Film & Video      USD  2016-05-21   6,000.00
# 324244  Playing Cards         Games      USD  2016-06-14  25,000.00
# 324571          Music         Music      USD  2016-04-29   7,000.00
# 325711          Music         Music      DKK  2016-05-18  15,000.00
# 326852          Music         Music      USD  2016-05-11   8,000.00
# 332040   Film & Video  Film & Video      AUD  2016-06-07   4,500.00
# 338430          Music         Music      USD  2016-04-25   5,500.00
# 338481     Publishing    Publishing      USD  2016-04-28   5,000.00
# 338549          Music         Music      EUR  2016-05-08   5,000.00
# 340562          Music         Music      USD  2016-05-27   3,500.00
# 341257          Music         Music      USD  2016-05-28   3,795.00
# 344315          Music         Music      EUR  2016-05-07   5,500.00
# 344755   Film & Video  Film & Video      USD  2016-05-12   1,500.00
# 345389   Film & Video  Film & Video      USD  2016-07-07  18,000.00
# 348821   Film & Video  Film & Video      USD  2016-05-12   7,500.00
# 350302          Music         Music      USD  2016-04-26   6,500.00
# 356090          Music         Music      GBP  2016-04-23     750.00
# 360017           Food          Food      EUR  2016-06-20  28,493.00
# 360465          Music         Music      USD  2016-05-31   3,500.00
# 363806   Film & Video  Film & Video      EUR  2016-05-28   1,500.00
# 367884          Music         Music      USD  2013-04-11   2,500.00
# 368641          Music         Music      USD  2016-04-29   2,500.00
# 368860          Music         Music      USD  2016-05-24   8,000.00
# 368889          Music         Music      USD  2016-05-09   7,500.00
# 371277         Events          Food      USD  2016-05-05  25,000.00
# 371387          Print    Journalism      EUR  2016-04-28  15,000.00
# 372375          Music         Music      USD  2016-04-28   3,500.00
# 375359   Film & Video  Film & Video      USD  2016-05-06   9,000.00
# 378188   Film & Video  Film & Video      USD  2016-05-14   2,000.00
#
#                    launched      pledged       state  backers country  \
# 2457    2016-04-26 19:46:26     5,170.00  successful        0    N,0"
# 4338    2016-04-11 07:20:59     1,375.00    canceled        0    N,0"
# 4892    2016-04-11 19:29:17     5,296.00  successful        0    N,0"
# 5353    2016-04-21 16:14:28     5,077.00  successful        0    N,0"
# 5597    2016-04-04 23:32:00     3,502.13  successful        0    N,0"
# 8260    2016-03-25 17:20:21     3,787.00  successful        0    N,0"
# 10086   2016-05-15 20:55:34         0.00      failed        0    N,0"
# 10527   2016-04-15 01:16:42     3,628.00      failed        0    N,0"
# 11191   2016-04-19 20:05:26         1.00      failed        0    N,0"
# 13001   2014-04-29 17:18:03 2,762,571.78  successful        0    N,0"
# 13048   2016-04-11 12:42:02     3,606.00  successful        0    N,0"
# 14385   2016-04-30 13:26:24       618.00      failed        0    N,0"
# 14527   2016-03-25 16:56:43     4,051.00  successful        0    N,0"
# 16769   2013-03-26 05:06:11     4,593.00  successful        0    N,0"
# 17525   2016-04-03 15:45:53         0.00      failed        0    N,0"
# 17563   2016-04-02 10:19:30       155.00      failed        0    N,0"
# 18716   2016-03-12 17:27:03        46.00      failed        0    N,0"
# 21385   2016-03-28 20:38:22     8,263.45  successful        0    N,0"
# 23172   2016-04-10 18:54:35     2,305.00  successful        0    N,0"
# 23936   2016-04-08 06:27:58        10.00      failed        0    N,0"
# 24079   2016-04-17 16:16:23       392.00      failed        0    N,0"
# 25975   2016-04-28 17:59:47     6,010.00  successful        0    N,0"
# 32215   2016-04-22 01:29:41        33.00      failed        0    N,0"
# 32500   2016-04-22 01:05:30     4,001.00  successful        0    N,0"
# 38162   2016-02-29 10:29:25         7.00      failed        0    N,0"
# 42065   2016-04-23 06:19:25         0.00    canceled        0    N,0"
# 44594   2016-04-28 11:28:39         0.00    canceled        0    N,0"
# 44765   2016-04-19 22:40:28     6,093.69  successful        0    N,0"
# 44910   2016-05-04 03:31:24     1,200.00  successful        0    N,0"
# 46952   2016-04-22 18:31:43     3,700.00  successful        0    N,0"
# ...                     ...          ...         ...      ...     ...
# 323142  2016-04-30 20:00:00     2,060.00  successful        0    N,0"
# 324209  2016-04-21 05:30:46     6,525.60  successful        0    N,0"
# 324244  2016-04-30 07:18:48    16,655.00   suspended        0    N,0"
# 324571  2016-03-30 20:14:45     8,025.00  successful        0    N,0"
# 325711  2016-04-18 12:39:04         5.00      failed        0    N,0"
# 326852  2016-04-11 13:53:47     2,975.00      failed        0    N,0"
# 332040  2016-05-18 06:53:04         0.00    canceled        0    N,0"
# 338430  2016-03-25 06:44:28     5,514.00  successful        0    N,0"
# 338481  2016-02-29 01:52:16       786.00      failed        0    N,0"
# 338549  2016-04-08 20:13:05         0.00      failed        0    N,0"
# 340562  2016-04-12 22:06:19       701.00      failed        0    N,0"
# 341257  2016-05-20 21:01:56     4,497.00  successful        0    N,0"
# 344315  2016-04-07 23:24:41     5,955.00  successful        0    N,0"
# 344755  2016-04-12 19:21:59     1,500.00  successful        0    N,0"
# 345389  2016-05-08 07:47:51         0.00    canceled        0    N,0"
# 348821  2016-04-07 15:35:33     7,623.00  successful        0    N,0"
# 350302  2016-03-17 20:04:13     8,889.00  successful        0    N,0"
# 356090  2016-02-23 22:39:22         1.00      failed        0    N,0"
# 360017  2016-05-17 13:26:09       239.00    canceled        0    N,0"
# 360465  2016-05-01 19:40:30     3,646.00  successful        0    N,0"
# 363806  2016-04-28 22:12:22        15.00      failed        0    N,0"
# 367884  2013-03-12 20:03:33     2,780.00  successful        0    N,0"
# 368641  2016-03-30 17:23:28     2,560.00  successful        0    N,0"
# 368860  2016-03-25 03:54:04     9,625.00  successful        0    N,0"
# 368889  2016-04-09 02:21:45     1,408.00      failed        0    N,0"
# 371277  2016-04-05 06:01:09         0.00        live        0    N,0"
# 371387  2016-03-29 16:02:57     1,933.00      failed        0    N,0"
# 372375  2016-04-05 18:56:21     3,686.00  successful        0    N,0"
# 375359  2016-03-07 04:17:33         2.00      failed        0    N,0"
# 378188  2016-04-14 01:27:27     2,300.00  successful        0    N,0"
#
#         usd pledged  usd_pledged_real  usd_goal_real
# 2457            nan          5,170.00       5,000.00
# 4338            nan          1,375.00       2,500.00
# 4892            nan          5,296.00       5,000.00
# 5353            nan          5,077.00       3,800.00
# 5597            nan          3,502.13       3,500.00
# 8260            nan          3,787.00       3,500.00
# 10086           nan              0.00       8,659.38
# 10527           nan          2,768.20       4,578.06
# 11191           nan              1.00       1,500.00
# 13001           nan      2,762,571.78     200,000.00
# 13048           nan          5,195.74       5,043.01
# 14385           nan            618.00       4,500.00
# 14527           nan          3,145.43       3,105.83
# 16769           nan          4,593.00       3,750.00
# 17525           nan              0.00       5,000.00
# 17563           nan            155.00       7,500.00
# 18716           nan             46.00       1,200.00
# 21385           nan          8,263.45       8,000.00
# 23172           nan          2,305.00       1,800.00
# 23936           nan             10.00       3,500.00
# 24079           nan            571.09       2,913.71
# 25975           nan          6,010.00       6,000.00
# 32215           nan             33.00       5,000.00
# 32500           nan          4,001.00       4,000.00
# 38162           nan             10.23       7,307.27
# 42065           nan              0.00       3,200.00
# 44594           nan              0.00      15,000.00
# 44765           nan          6,093.69       5,000.00
# 44910           nan          1,200.00       1,200.00
# 46952           nan          3,700.00       3,500.00
# ...             ...               ...            ...
# 323142          nan          2,060.00       2,000.00
# 324209          nan          6,525.60       6,000.00
# 324244          nan         16,655.00      25,000.00
# 324571          nan          8,025.00       7,000.00
# 325711          nan              0.75       2,262.82
# 326852          nan          2,975.00       8,000.00
# 332040          nan              0.00       3,330.37
# 338430          nan          5,514.00       5,500.00
# 338481          nan            786.00       5,000.00
# 338549          nan              0.00       5,674.02
# 340562          nan            701.00       3,500.00
# 341257          nan          4,497.00       3,795.00
# 344315          nan          6,757.75       6,241.42
# 344755          nan          1,500.00       1,500.00
# 345389          nan              0.00      18,000.00
# 348821          nan          7,623.00       7,500.00
# 350302          nan          8,889.00       6,500.00
# 356090          nan              1.46       1,096.09
# 360017          nan            264.48      31,530.32
# 360465          nan          3,646.00       3,500.00
# 363806          nan             16.73       1,673.10
# 367884          nan          2,780.00       2,500.00
# 368641          nan          2,560.00       2,500.00
# 368860          nan          9,625.00       8,000.00
# 368889          nan          1,408.00       7,500.00
# 371277          nan              0.00      25,000.00
# 371387          nan          2,204.21      17,104.54
# 372375          nan          3,686.00       3,500.00
# 375359          nan              2.00       9,000.00
# 378188          nan          2,300.00       2,000.00
#
# [235 rows x 15 columns]

# %%
temp.country.unique()
# Out:
# array(['N,0"'], dtype=object)

# %%
temp.backers.unique()
# Out:
# array([0])

# %%
temp.shape
# Out:
# (3797, 15)

# %%
temp_2 = ks_df.loc[ks_df['backers'] == 0]

# %%
ks_df.loc[ks_df['country'] == 'N,0"'].shape
# Out:
# (3797, 15)

# %%
ks_df_2 = ks_df.dropna()

# %%
ks_df_2.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline      goal  \
# 0          Poetry    Publishing      GBP  2015-10-09  1,000.00
# 1  Narrative Film  Film & Video      USD  2017-11-01 30,000.00
# 2  Narrative Film  Film & Video      USD  2013-02-26 45,000.00
# 3           Music         Music      USD  2012-04-16  5,000.00
# 4    Film & Video  Film & Video      USD  2015-08-29 19,500.00
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28     0.00    failed        0      GB         0.00
# 1  2017-09-02 04:43:57 2,421.00    failed       15      US       100.00
# 2  2013-01-12 00:20:50   220.00    failed        3      US       220.00
# 3  2012-03-17 03:24:11     1.00    failed        1      US         1.00
# 4  2015-07-04 08:35:03 1,283.00  canceled       14      US     1,283.00
#
#    usd_pledged_real  usd_goal_real
# 0              0.00       1,533.95
# 1          2,421.00      30,000.00
# 2            220.00      45,000.00
# 3              1.00       5,000.00
# 4          1,283.00      19,500.00

# %%
ks_df_2.country.unique()
# Out:
# array(['GB', 'US', 'CA', 'AU', 'NO', 'IT', 'DE', 'IE', 'MX', 'ES', 'SE',
#        'FR', 'NL', 'NZ', 'CH', 'AT', 'DK', 'BE', 'HK', 'LU', 'SG', 'JP'],
#       dtype=object)
